# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

import mlflow
import mlflow.sklearn

from src.data_pipeline.load_data import DataLoader
from src.data_pipeline.preprocess import Feature_Engineer, Preprocessor

# %%
loader = DataLoader(PROJECT_ROOT/"data")

customers = loader.load_customers()
tx = loader.load_transactions()
prods = loader.load_products()

# %%
customers.head()
# Out:
#   customer_id              name                       email  \
# 0    CUST0001        Laura Hill   patrickcooke@hamilton.com
# 1    CUST0002  Kimberly Burnett     stonebrenda@hotmail.com
# 2    CUST0003      Abigail West  williamsbailey@hotmail.com
# 3    CUST0004   Carolyn Rowland        kevinshah@conway.com
# 4    CUST0005    Amanda Johnson        melissa32@arnold.org
#
#         phone_number country             city  age gender  \
# 0  +1 (830) 982-9806      CA       South Lisa   61      F
# 1     (938) 909-3033      US   Lake Priscilla   33      M
# 2  +1 (265) 189-5206      CA  North Tinahaven   45  Other
# 3  +234 690 602 6127      NG   Catherinehaven   49      M
# 4    +44 7914 177971      UK       Jorgeburgh   59      F
#
#                          interests signup_date last_purchase_date  \
# 0                  Beauty, Fashion  2022-08-17         2025-02-13
# 1       Books, Sports, Electronics  2022-08-15         2024-04-17
# 2              Electronics, Sports  2022-12-18         2025-07-05
# 3           Books, Home Appliances  2023-03-19         2024-10-03
# 4  Sports, Home Appliances, Beauty  2023-01-09         2023-06-11
#
#    total_spent  purchase_frequency  churn
# 0       225.82                 1.9      0
# 1      3001.28                 4.2      1
# 2      3934.91                 2.1      0
# 3       162.00                 2.4      1
# 4      2233.89                 3.8      1

# %%
prods.head()
# Out:
#   product_id                         product_name     category  \
# 0   PROD0001        Sharable bifurcated algorithm       Beauty
# 1   PROD0002            Reactive explicit product      Fashion
# 2   PROD0003           Sharable motivating portal       Beauty
# 3   PROD0004  Universal fault-tolerant initiative       Sports
# 4   PROD0005        Down-sized incremental matrix  Electronics
#
#                                          description   price  stock_status
# 0  Development say quality throughout beautiful. ...   60.11  Out of Stock
# 1  Young catch management sense technology. Physi...  115.49      In Stock
# 2               Hear claim well two. Out major born.  371.63      In Stock
# 3     Best issue interest level. Pull worker better.  213.85      In Stock
# 4  Ten total clearly able hospital. Expect recent...  113.23      In Stock

# %%
tx.head()
# Out:
#   transaction_id customer_id product_id purchase_date  quantity  total_price
# 0        TX00001    CUST0001   PROD0131    2022-09-14         2       124.18
# 1        TX00002    CUST0001   PROD0100    2023-11-03         5      2460.05
# 2        TX00003    CUST0001   PROD0041    2022-09-17         3       249.87
# 3        TX00004    CUST0002   PROD0086    2023-09-28         3       116.76
# 4        TX00005    CUST0002   PROD0051    2022-12-13         4      1536.36

# %%
prep = Preprocessor()
clean_cutomers = prep.clean_customer_data(customers)
clean_tx = prep.clean_tx_data(tx)
clean_prods = prep.clean_product_data(prods)

# %%
feat_eng = Feature_Engineer()
customers_eng = feat_eng.engineer_customer_features(customers=clean_cutomers, products=prods, transactions=clean_tx)
products_eng = feat_eng.engineer_product_features(transactions=clean_tx, products=clean_prods)
tx_eng = feat_eng.engineer_tx_features(clean_tx)

# %%
customers.columns
# Out:
# Index(['customer_id', 'name', 'email', 'phone_number', 'country', 'city',
#        'age', 'gender', 'interests', 'signup_date', 'last_purchase_date',
#        'total_spent', 'purchase_frequency', 'churn'],
#       dtype='object')

# %%
# Merge datasets

merged = feat_eng.merge_all_datasets(tx_eng, customers_eng, products_eng)
merged.head(5)
# Out:
# INFO:src.utils.logger:datasets merged...
#   transaction_id customer_id product_id             purchase_date  quantity  \
# 0        TX00001    CUST0001   PROD0131 2022-09-14 00:00:00+00:00         2
# 1        TX00003    CUST0001   PROD0041 2022-09-17 00:00:00+00:00         3
# 2        TX00002    CUST0001   PROD0100 2023-11-03 00:00:00+00:00         5
# 3        TX00006    CUST0002   PROD0084 2022-08-27 00:00:00+00:00         1
# 4        TX00005    CUST0002   PROD0051 2022-12-13 00:00:00+00:00         4
#
#    total_price  days_since_last_purchase  \
# 0       124.18                     143.5
# 1       249.87                       3.0
# 2      2460.05                     412.0
# 3       241.01                     143.5
# 4      1536.36                     108.0
#
#                                     product_name         category  \
# 0                  extended radical productivity      Electronics
# 1         future-proofed client-driven benchmark  Home Appliances
# 2  re-contextualized mission-critical throughput           Sports
# 3      multi-lateral transitional knowledge user           Sports
# 4         future-proofed coherent implementation           Sports
#
#                                          description  ...  \
# 0  Beat painting heavy shake. Sort continue book ...  ...
# 1  Small control see the face also.\nOwner up fri...  ...
# 2  Which learn leave only agree break. Him small ...  ...
# 3  Service develop game stop. Natural hear blood ...  ...
# 4  First blood accept final growth especially. Be...  ...
#
#                 signup_date last_purchase_date  total_spent  \
# 0 2022-08-17 00:00:00+00:00         2025-02-13      2834.10
# 1 2022-08-17 00:00:00+00:00         2025-02-13      2834.10
# 2 2022-08-17 00:00:00+00:00         2025-02-13      2834.10
# 3 2022-08-15 00:00:00+00:00         2024-04-17      1894.13
# 4 2022-08-15 00:00:00+00:00         2024-04-17      1894.13
#
#    purchase_frequency churn num_purchases avg_purchase_value recency_days  \
# 0                 1.9     0             3         944.700000          773
# 1                 1.9     0             3         944.700000          773
# 2                 1.9     0             3         944.700000          773
# 3                 4.2     1             3         631.376667          809
# 4                 4.2     1             3         631.376667          809
#
#   days_since_signup  top_category
# 0              1216   Electronics
# 1              1216   Electronics
# 2              1216   Electronics
# 3              1218        Sports
# 4              1218        Sports
#
# [5 rows x 32 columns]

# %%
customers_eng.head()
# Out:
#                          name                       email       phone_number  \
# customer_id
# CUST0001           laura hill   patrickcooke@hamilton.com  +1 (830) 982-9806
# CUST0002     kimberly burnett     stonebrenda@hotmail.com     (938) 909-3033
# CUST0003         abigail west  williamsbailey@hotmail.com  +1 (265) 189-5206
# CUST0004      carolyn rowland        kevinshah@conway.com  +234 690 602 6127
# CUST0005       amanda johnson        melissa32@arnold.org    +44 7914 177971
#
#             country             city  age gender  \
# customer_id
# CUST0001         CA       South Lisa   61      F
# CUST0002         US   Lake Priscilla   33      M
# CUST0003         CA  North Tinahaven   45  Other
# CUST0004         NG   Catherinehaven   49      M
# CUST0005         UK       Jorgeburgh   59      F
#
#                                    interests               signup_date  \
# customer_id
# CUST0001                     Beauty, Fashion 2022-08-17 00:00:00+00:00
# CUST0002          Books, Sports, Electronics 2022-08-15 00:00:00+00:00
# CUST0003                 Electronics, Sports 2022-12-18 00:00:00+00:00
# CUST0004              Books, Home Appliances 2023-03-19 00:00:00+00:00
# CUST0005     Sports, Home Appliances, Beauty 2023-01-09 00:00:00+00:00
#
#             last_purchase_date  total_spent  purchase_frequency  churn  \
# customer_id
# CUST0001            2025-02-13      2834.10                 1.9      0
# CUST0002            2024-04-17      1894.13                 4.2      1
# CUST0003            2025-07-05      3938.37                 2.1      0
# CUST0004            2024-10-03      2482.50                 2.4      1
# CUST0005            2023-06-11      1415.28                 3.8      1
#
#              num_purchases  avg_purchase_value  recency_days  \
# customer_id
# CUST0001                 3          944.700000           773
# CUST0002                 3          631.376667           809
# CUST0003                 3         1312.790000           213
# CUST0004                 3          827.500000           568
# CUST0005                 3          471.760000           363
#
#              days_since_signup top_category
# customer_id
# CUST0001                  1216  Electronics
# CUST0002                  1218       Sports
# CUST0003                  1093        Books
# CUST0004                  1002      Fashion
# CUST0005                  1071      Fashion

# %%
target = "churn"

feature_cols = [
    'total_spent', 'total_price', 'days_since_last_purchase', 'product_name', 'category', 
    'popularity_score', 'category_popularity', 'country', 'city', 'age', 'gender', 'interests', 
    'purchase_frequency', 'num_purchases', 'avg_purchase_value', 'recency_days', 'top_category'
]

X = merged[feature_cols]
y = merged[target]

X
# Out:
#       total_spent  total_price  days_since_last_purchase  \
# 0         2834.10       124.18                     143.5
# 1         2834.10       249.87                       3.0
# 2         2834.10      2460.05                     412.0
# 3         1894.13       241.01                     143.5
# 4         1894.13      1536.36                     108.0
# ...           ...          ...                       ...
# 5995      5069.95      2318.15                      92.0
# 5996      5069.95      2441.10                      28.0
# 5997      3341.03       909.44                     143.5
# 5998      3341.03      2047.35                     103.0
# 5999      3341.03       384.24                      33.0
#
#                                        product_name         category  \
# 0                     extended radical productivity      Electronics
# 1            future-proofed client-driven benchmark  Home Appliances
# 2     re-contextualized mission-critical throughput           Sports
# 3         multi-lateral transitional knowledge user           Sports
# 4            future-proofed coherent implementation           Sports
# ...                                             ...              ...
# 5995                        virtual cohesive matrix            Books
# 5996           exclusive 24hour process improvement          Fashion
# 5997        customer-focused value-added neural-net          Fashion
# 5998          exclusive dynamic process improvement           Beauty
# 5999                      inverse analyzing adapter      Electronics
#
#       popularity_score  category_popularity country             city  age  \
# 0                   27                 1028      CA       South Lisa   61
# 1                   38                  929      CA       South Lisa   61
# 2                   35                  875      CA       South Lisa   61
# 3                   37                  875      US   Lake Priscilla   33
# 4                   30                  875      US   Lake Priscilla   33
# ...                ...                  ...     ...              ...  ...
# 5995                28                  819      US  West Andrewfurt   28
# 5996                23                 1057      US  West Andrewfurt   28
# 5997                30                 1057      CA  Lake Willieberg   57
# 5998                37                 1292      CA  Lake Willieberg   57
# 5999                26                 1028      CA  Lake Willieberg   57
#
#      gender                   interests  purchase_frequency  num_purchases  \
# 0         F             Beauty, Fashion                 1.9              3
# 1         F             Beauty, Fashion                 1.9              3
# 2         F             Beauty, Fashion                 1.9              3
# 3         M  Books, Sports, Electronics                 4.2              3
# 4         M  Books, Sports, Electronics                 4.2              3
# ...     ...                         ...                 ...            ...
# 5995      F                     Fashion                 2.2              3
# 5996      F                     Fashion                 2.2              3
# 5997      F               Sports, Books                 3.3              3
# 5998      F               Sports, Books                 3.3              3
# 5999      F               Sports, Books                 3.3              3
#
#       avg_purchase_value  recency_days top_category
# 0             944.700000           773  Electronics
# 1             944.700000           773  Electronics
# 2             944.700000           773  Electronics
# 3             631.376667           809       Sports
# 4             631.376667           809       Sports
# ...                  ...           ...          ...
# 5995         1689.983333           359        Books
# 5996         1689.983333           359        Books
# 5997         1113.676667           532  Electronics
# 5998         1113.676667           532  Electronics
# 5999         1113.676667           532  Electronics
#
# [6000 rows x 17 columns]

# %%
num_features = [col for col in X.columns if X[col].dtype != "object"]
cat_features = [col for col in X.columns if X[col].dtype == "object"]

# %%
transformed = ColumnTransformer([
    ("num", StandardScaler(), num_features),
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

X_train
# Out:
#       total_spent  total_price  days_since_last_purchase  \
# 1591      2668.57       218.49                     253.0
# 5499      2394.21       936.16                     143.5
# 4516      2161.66       842.76                      52.0
# 1739      3141.53       461.96                     153.0
# 5662       973.22        50.91                      53.0
# ...           ...          ...                       ...
# 3080      3303.89      2452.30                      53.0
# 3344      2465.95      1381.24                     179.0
# 4900      3035.34        30.82                     151.0
# 1877      1260.31       160.23                     197.0
# 779       3979.68       212.22                     131.0
#
#                                       product_name     category  \
# 1591        optimized multi-tasking infrastructure        Books
# 5499               user-centric multimedia ability       Beauty
# 4516           balanced clear-thinking methodology  Electronics
# 1739                     reactive explicit product      Fashion
# 5662                     balanced dynamic leverage  Electronics
# ...                                            ...          ...
# 3080             stand-alone web-enabled migration      Fashion
# 3344                         total regional matrix      Fashion
# 4900               visionary background initiative        Books
# 1877  organic contextually-based pricing structure       Beauty
# 779    multi-channeled clear-thinking secured line        Books
#
#       popularity_score  category_popularity country               city  age  \
# 1591                34                  819      CA         Rogersport   47
# 5499                33                 1292      IN    South Josephton   67
# 4516                27                 1028      CA  West Kristinmouth   54
# 1739                30                 1057      CA          Dixonbury   41
# 5662                43                 1028      IN       South Ashley   18
# ...                ...                  ...     ...                ...  ...
# 3080                32                 1057      US          West Mark   46
# 3344                28                 1057      UK    Figueroachester   53
# 4900                31                  819      IN   South Laurenberg   38
# 1877                29                 1292      NG       South Robert   68
# 779                 27                  819      US          East Tina   52
#
#      gender                             interests  purchase_frequency  \
# 1591  Other   Electronics, Home Appliances, Books                 1.8
# 5499  Other                        Sports, Beauty                 1.0
# 4516      F                Books, Beauty, Fashion                 4.2
# 1739  Other               Home Appliances, Sports                 4.3
# 5662      M                  Fashion, Electronics                 3.4
# ...     ...                                   ...                 ...
# 3080      F  Beauty, Electronics, Home Appliances                 4.7
# 3344      M                           Electronics                 2.2
# 4900  Other                                Sports                 4.3
# 1877      M                       Home Appliances                 3.7
# 779   Other           Electronics, Fashion, Books                 1.8
#
#       num_purchases  avg_purchase_value  recency_days top_category
# 1591              3          889.523333           198       Sports
# 5499              3          798.070000           260       Beauty
# 4516              3          720.553333           541       Sports
# 1739              3         1047.176667           178      Fashion
# 5662              3          324.406667           239       Beauty
# ...             ...                 ...           ...          ...
# 3080              3         1101.296667           249        Books
# 3344              3          821.983333           266       Sports
# 4900              3         1011.780000           249        Books
# 1877              3          420.103333           456       Beauty
# 779               3         1326.560000           167       Beauty
#
# [4800 rows x 17 columns]

# %%
models = {
    "logistic_regression": LogisticRegression(max_iter=1000),
    "random_forest": RandomForestClassifier(n_estimators=200),
    "catboost": CatBoostClassifier(verbose=0),
    "lightgbm": LGBMClassifier(n_estimators=300, n_jobs=4, verbose=-1)
}

models.items()
# Out:
# dict_items([('logistic_regression', LogisticRegression(max_iter=1000)), ('random_forest', RandomForestClassifier(n_estimators=200)), ('catboost', <catboost.core.CatBoostClassifier object at 0x000001430F75D2B0>), ('lightgbm', LGBMClassifier(n_estimators=300, n_jobs=4, verbose=-1))])

# %%
mlflow.set_experiment("agentic_churn_modeling")

results = {}

for model_name, model in models.items():
    with mlflow.start_run(run_name=model_name):

        if model_name == "catboost":
            cat_features = X_train.select_dtypes(
                include=["object", "category"]
            ).columns.tolist()

            cat_feature_indices = [
                X_train.columns.get_loc(col) for col in cat_features
            ]

            model.fit(
                X_train,
                y_train,
                cat_features=cat_feature_indices
            )

            proba = model.predict_proba(X_test)[:, 1]

            mlflow.log_params(model.get_params())

            auc = roc_auc_score(y_test, proba)
            mlflow.log_metric("auc", auc)

            mlflow.catboost.log_model(model, artifact_path="model")
            results[model_name] = auc
            
        else:

            pipe = Pipeline([
                ("transformed", transformed),
                ("model", model)
            ])

            pipe.fit(X_train, y_train)
            preds = pipe.predict(X_test)
            proba = pipe.predict_proba(X_test)[:, 1]

            mlflow.log_param("train_size", X_train.shape[0])
            mlflow.log_param("test_size", X_test.shape[0])
            mlflow.log_param("num_features", X_train.shape[1])

            mlflow.log_params(pipe.named_steps["model"].get_params())

            auc = roc_auc_score(y_test, proba)
            mlflow.log_metric("auc", auc)

            
            mlflow.sklearn.log_model(pipe, artifact_path="model")

            results[model_name] = auc
# Out:
# 2025/12/15 01:48:59 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/15 01:48:59 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/15 01:48:59 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/15 01:48:59 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/15 01:48:59 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2025/12/15 01:48:59 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2025/12/15 01:48:59 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2025/12/15 01:48:59 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2025/12/15 01:48:59 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2025/12/15 01:49:00 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2025/12/15 01:49:01 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2025/12/15 01:49:02 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2025/12/15 01:49:02 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/15 01:49:02 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/15 01:49:02 INFO mlflow.tracking.fluent: Experiment with name 'agentic_churn_modeling' does not exist. Creating a new experiment.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): config.mlflow-telemetry.io:443
# DEBUG:git.cmd:Popen(['git', 'version'], cwd=c:\Users\HP\projects\AI\ai_marketing_agents\notebooks, stdin=None, shell=False, universal_newlines=False)
# 2025/12/15 01:49:02 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh(<full-path-to-git-executable>)
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
#     - warn|w|warning|log|l|1: for a warning message (logging level CRITICAL, displayed by default)
#     - error|e|exception|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
# 2025/12/15 01:49:03 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# DEBUG:urllib3.connectionpool:https://config.mlflow-telemetry.io:443 "GET /3.7.0.json HTTP/1.1" 200 215
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.mlflow-telemetry.io:443
# DEBUG:urllib3.connectionpool:https://api.mlflow-telemetry.io:443 "POST /log HTTP/1.1" 200 30
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.mlflow-telemetry.io:443
# DEBUG:urllib3.connectionpool:https://api.mlflow-telemetry.io:443 "POST /log HTTP/1.1" 200 30
# 2025/12/15 01:49:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.mlflow-telemetry.io:443
# DEBUG:urllib3.connectionpool:https://api.mlflow-telemetry.io:443 "POST /log HTTP/1.1" 200 30
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.mlflow-telemetry.io:443
# DEBUG:urllib3.connectionpool:https://api.mlflow-telemetry.io:443 "POST /log HTTP/1.1" 200 30
# 2025/12/15 01:51:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.mlflow-telemetry.io:443
# DEBUG:urllib3.connectionpool:https://api.mlflow-telemetry.io:443 "POST /log HTTP/1.1" 200 30
# c:\Users\HP\projects\AI\ai_marketing_agents\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\projects\AI\ai_marketing_agents\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025/12/15 01:51:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.mlflow-telemetry.io:443
# DEBUG:urllib3.connectionpool:https://api.mlflow-telemetry.io:443 "POST /log HTTP/1.1" 200 30
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.mlflow-telemetry.io:443
# DEBUG:urllib3.connectionpool:https://api.mlflow-telemetry.io:443 "POST /log HTTP/1.1" 200 30

# %%
print("AUC Scores:")
for k, v in results.items():
    print(k, v)

best_model = max(results, key=results.get)
print("Best Model:", best_model)
# Out:
# AUC Scores:
# logistic_regression 0.9149372653173369
# random_forest 0.9703287846872425
# catboost 0.9988680282077114
# lightgbm 0.9705504167048266
# Best Model: catboost

# %%
if best_model == "catboost":
    cat_features = X_train.select_dtypes(
        include=["object", "category"]
    ).columns.tolist()

    cat_feature_indices = [
        X_train.columns.get_loc(col) for col in cat_features
    ]

    model = models[best_model]

    model.fit(
        X_train,
        y_train,
        cat_features=cat_feature_indices
    )

    preds = model.predict(X_test)
    proba = model.predict_proba(X_test)[:, 1]

else:

    best_pipeline = Pipeline([
        ("preprocess", transformed),
        ("model", models[best_model])
    ])
    best_pipeline.fit(X_train, y_train)
    preds = best_pipeline.predict(X_test)
    proba = best_pipeline.predict_proba(X_test)[:, 1]

print(classification_report(y_test, preds))
print("AUC:", roc_auc_score(y_test, proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95       305
#            1       0.97      1.00      0.99       895
#
#     accuracy                           0.98      1200
#    macro avg       0.98      0.96      0.97      1200
# weighted avg       0.98      0.98      0.98      1200
#
# AUC: 0.9988680282077114

# %%
import mlflow
print(mlflow.get_tracking_uri())

mlflow.search_runs()
# Out:
# sqlite:///mlflow.db
#                              run_id experiment_id    status  \
# 0  b85084079de944949ad7dcb63d396569             1  FINISHED
# 1  8015321d1146435da910daceb42398a9             1  FINISHED
# 2  ee49d7de572444aaa6252f3705464292             1  FINISHED
# 3  3c84752ccf6747a7abceb0bdced95cf9             1  FINISHED
#
#                                         artifact_uri  \
# 0  file:c:/Users/HP/projects/AI/ai_marketing_agen...
# 1  file:c:/Users/HP/projects/AI/ai_marketing_agen...
# 2  file:c:/Users/HP/projects/AI/ai_marketing_agen...
# 3  file:c:/Users/HP/projects/AI/ai_marketing_agen...
#
#                         start_time                         end_time  \
# 0 2025-12-15 00:51:33.691000+00:00 2025-12-15 00:51:53.401000+00:00
# 1 2025-12-15 00:50:00.625000+00:00 2025-12-15 00:51:33.640000+00:00
# 2 2025-12-15 00:49:30.722000+00:00 2025-12-15 00:50:00.577000+00:00
# 3 2025-12-15 00:49:02.799000+00:00 2025-12-15 00:49:30.687000+00:00
#
#    metrics.auc params.min_child_weight params.test_size  \
# 0     0.970550                   0.001             1200
# 1     0.998868                    None             None
# 2     0.970329                    None             1200
# 3     0.914937                    None             1200
#
#   params.importance_type  ... params.l1_ratio params.solver params.tol  \
# 0                  split  ...            None          None       None
# 1                   None  ...            None          None       None
# 2                   None  ...            None          None       None
# 3                   None  ...             0.0         lbfgs     0.0001
#
#   params.C params.penalty params.fit_intercept tags.mlflow.source.type  \
# 0     None           None                 None                   LOCAL
# 1     None           None                 None                   LOCAL
# 2     None           None                 None                   LOCAL
# 3      1.0     deprecated                 True                   LOCAL
#
#    tags.mlflow.runName tags.mlflow.user  \
# 0             lightgbm               HP
# 1             catboost               HP
# 2        random_forest               HP
# 3  logistic_regression               HP
#
#                              tags.mlflow.source.name
# 0  c:\Users\HP\projects\AI\ai_marketing_agents\ve...
# 1  c:\Users\HP\projects\AI\ai_marketing_agents\ve...
# 2  c:\Users\HP\projects\AI\ai_marketing_agents\ve...
# 3  c:\Users\HP\projects\AI\ai_marketing_agents\ve...
#
# [4 rows x 56 columns]
